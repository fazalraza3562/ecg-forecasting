# %% [markdown]
# # Explainability demo
#
# Walk through attention overlays, input-gradient saliency, Grad-CAM, and SHAP DeepExplainer summaries on representative true positives and instructive failure cases.
